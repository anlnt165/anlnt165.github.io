# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# Access dataframe
df = pd.read_csv('DigiDB_digimonlist.csv')
# print(df)

# %%
# Get columns headers
headers = list(df.columns.values)

analysis_df = df[['Lv50 SP','Lv50 Atk', 'Lv50 Def', 'Lv50 Int', 'Lv50 Spd']]
# print(analysis_df)

# %%
sns.boxplot(data = analysis_df)
# Out:
# <Axes: >
